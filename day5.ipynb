# %%
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn
# !pip install joblib
# Out:
# ...
#      ---------------------------------------- 11.4/11.4 MB 2.3 MB/s eta 0:00:00
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# ...
#      ---------------------------------------- 15.9/15.9 MB 7.7 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 25.2 is available.
# You should consider upgrading via the 'C:\Users\rubah\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...
#      ---------------------------------------- 7.8/7.8 MB 3.4 MB/s eta 0:00:00
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# ...
#      ---------------------------------------- 7.0/7.0 MB 4.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 55.8/55.8 KB 414.6 kB/s eta 0:00:00
# ...
#      -------------------------------------- 211.8/211.8 KB 1.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\rubah\\OneDrive\\Desktop\\ML\\employee_attrition_data.csv")
display(df.head(10))
# Out:
#    Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing        Manager                 9
# 1            1   53  Female        Sales       Engineer                10
# 2            2   59  Female    Marketing        Analyst                 8
# 3            3   42  Female  Engineering        Manager                 1
# 4            4   44  Female        Sales       Engineer                10
# 5            5   47    Male        Sales  HR Specialist                10
# 6            6   58    Male    Marketing  HR Specialist                 5
# 7            7   57  Female        Sales        Analyst                 8
# 8            8   34  Female      Finance     Accountant                 6
# 9            9   57  Female    Marketing       Engineer                 7
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# ...

# %%
print(df.isna().sum())
# isna() finds the missing values
# Out:
# Employee_ID              0
# Age                      0
# Gender                   0
# Department               0
# Job_Title                0
# Years_at_Company         0
# Satisfaction_Level       0
# Average_Monthly_Hours    0
# Promotion_Last_5Years    0
# Salary                   0
# Attrition                0
# dtype: int64

# %%
df.duplicated().sum
# finds the duplicate values
# Out:
# <bound method Series.sum of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool>

# %%
df.drop(columns="Employee_ID",inplace=True)
df.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.2 is available.
# You should consider upgrading via the 'c:\Users\rubah\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt

# %%
df["Job_Title"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Department")
plt.show()

# %%
df["Department"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Department")
plt.show()

# %%
df["Gender"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Gender count")
plt.show()

# %%
df["Average_Monthly_Hours"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Average Monthly Hours")
plt.show()

# %%
df.groupby("Job_Title")["Salary"].mean().sort_values(ascending=False).plot(kind="line")
plt.title("Average Salary by Job Title")
plt.xlabel("Job Title")
plt.ylabel(" Salary ")
plt.show()

# %%
df.groupby(["Department","Promotion_Last_5Years"])["Salary"].mean().reset_index()
# Out:
#     Department  Promotion_Last_5Years        Salary
# 0  Engineering                      0  65541.063636
# 1  Engineering                      1  62424.127660
# 2      Finance                      0  63390.145299
# 3      Finance                      1  62041.269663
# 4           HR                      0  63012.556701
# 5           HR                      1  65882.861702
# 6    Marketing                      0  65251.597826
# 7    Marketing                      1  66018.632653
# 8        Sales                      0  64295.846939
# 9        Sales                      1  67838.756757

# %%
x = df[["Years_at_Company","Satisfaction_Level","Average_Monthly_Hours"]]
y = df["Salary"]

# %%
! pip install scikit-learn
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 25.2 is available.
# You should consider upgrading via the 'C:\Users\rubah\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# Split train_test data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
# ...

# %%
x
# Out:
#      Years_at_Company  Satisfaction_Level  Average_Monthly_Hours
# 0                   9            0.586251                    151
# 1                  10            0.261161                    221
# 2                   8            0.304382                    184
# 3                   1            0.480779                    242
# 4                  10            0.636244                    229
# ..                ...                 ...                    ...
# 995                 3            0.377435                    239
# 996                 1            0.431152                    154
# 997                 3            0.647102                    206
# 998                 2            0.304813                    241
# 999                 1            0.940510                    159
#
# [1000 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train= scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.9143998 ,  0.38647326, -0.17633253],
#        [-0.56100857, -0.95914995,  0.09566752],
#        [-1.62118225, -1.02082305,  0.63966763],
#        ...,
#        [ 1.55933879,  0.90149189,  0.36766757],
#        [-0.20761735,  0.03697987, -1.36633277],
#        [-0.56100857,  0.55014033,  1.5236678 ]])

# %%
pip install joblib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.2 is available.
# You should consider upgrading via the 'c:\Users\rubah\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import joblib
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.49916511,  1.3263107 ,  0.40166758],
#        [ 1.20594756, -1.58402225, -0.89033268],
#        [ 1.55933879, -0.33306318, -0.0063325 ],
#        [ 1.55933879, -1.65636875, -1.09433272],
#        [-0.20761735, -0.47520719, -1.09433272],
#        [ 0.85255633,  0.97547749, -1.5023328 ],
#        [ 0.49916511, -0.34658733, -1.5023328 ],
#        [ 0.49916511,  0.91007203,  1.59166781],
#        [-0.20761735,  0.1687333 , -1.57033281],
#        [-0.20761735,  0.58166784,  1.55766781],
#        [ 0.85255633, -0.47502766,  0.57166761],
#        [ 0.14577388,  1.20877527, -0.5163326 ],
#        [ 0.85255633,  0.45973721, -0.55033261],
#        [ 0.49916511, -0.98807837,  1.69366783],
#        [ 0.49916511,  0.15919169,  0.12966753],
#        [-1.62118225,  0.33837422, -1.46833279],
#        [-0.9143998 , -1.59380604,  0.91166768],
#        [ 1.20594756,  1.38447116,  0.97966769],
#        [ 0.49916511,  0.45412516, -1.19633274],
#        [-1.26779103, -0.40458339,  0.97966769],
# ...

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

def results(predictions):
  print("Mean ansolute error on model is {}",format(mean_absolute_error(y_test,predictions)))
  print("Root mean squared error on model is {}",format(np.sqrt(mean_squared_error(y_test,predictions))))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
predictionlr = lr.predict(x_test)

# %%
results(predictionlr)
# Out:
# Mean ansolute error on model is {} 18474.128739359985
# Root mean squared error on model is {} 21146.089661684655

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

def results(predictions):
  print("Mean ansolute error on model is {}".format(mean_absolute_error(y_test,predictions)))
  print("Root mean squared error on model is {}".format(np.sqrt(mean_squared_error(y_test,predictions))))

results(predictionlr)
# Out:
# Mean ansolute error on model is 18474.128739359985
# Root mean squared error on model is 21146.089661684655

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

# %%
svrmodel = SVR()

# %%
param_gridsvr = {
    'C':[0.1, 1, 10],
    'epsilon':[0.1, 0.2, 0.3],
    'kernel':['linear','poly','rbf'],
    'degree':[2, 3, 4]
}

# %%
gridsvr = GridSearchCV(svrmodel,param_gridsvr)

# %%
gridsvr.fit(x_train,y_train.values.ravel())
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 4],
#                          'epsilon': [0.1, 0.2, 0.3],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
gridsvr.best_params_
# Out:
# {'C': 10, 'degree': 2, 'epsilon': 0.3, 'kernel': 'linear'}

# %%
predictionssvr = gridsvr.predict(x_test)

# %%
results(predictionssvr)
# Out:
# Mean ansolute error on model is 18451.298447605324
# Root mean squared error on model is 21101.9214567366

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rfmodel = RandomForestRegressor()

# %%
param_fridrfr = {
    "n_estimators": [2,3,4,5,6],
    "max_depth": [5,10,15],
}

# %%
gridrgr = GridSearchCV(estimator=rfmodel,param_grid=param_fridrfr,cv=5)

# %%
gridrgr.fit(x_train,y_train.values.ravel())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'n_estimators': [2, 3, 4, 5, 6]})

# %%
gridrgr.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 6}

# %%
predictionofrfr = gridrgr.predict(x_test)

# %%
lr
# Out:
# LinearRegression()

# %%
results(predictionofrfr)
# Out:
# Mean ansolute error on model is 18807.03815418226
# Root mean squared error on model is 21616.722392927302

# %%
lr
# Out:
# LinearRegression()

# %%
joblib.dump(lr,"model.pkl")
# Out:
# ['model.pkl']

# %%
x.columns
# Out:
# Index(['Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours'], dtype='object')
